# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Imports

# %%
import random
import pandas as pd
import numpy as np
from numpy.linalg import inv
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data

# %% [markdown]
# Define the path to the file containing the data

# %%
datafile = "lausanne-appart.csv"

# %% [markdown]
# Read the data

# %%
dataset = pd.read_csv(datafile)

# %% [markdown]
# Display first rows

# %%
dataset.head()
# Out:
#    living_area  nb_rooms  rent_price
# 0           69       3.0        1810
# 1           95       3.5        2945
# 2           21       1.5         685
# 3           20       1.0         720
# 4           33       1.5         830

# %%
# get numpy arrays from panda objects
rent_price = dataset.rent_price.values
living_area = dataset.living_area.values
print(type(rent_price))
print(rent_price.shape, living_area.shape)
# Out:
# <class 'numpy.ndarray'>
# (201,) (201,)

# %% [markdown]
# ## Part 1 - Visualize the data

# %% [markdown]
# a) Plot a histogram to visualize the distribution of the renting price

# %%
plt.figure(1, figsize=(8, 4))
plt.hist(rent_price)
plt.xlabel("Rent (CHF)")
plt.title("Rent distribution")
plt.xlim(np.min(rent_price), np.max(rent_price))
plt.show()

# %% [markdown]
# b) Plot a histogram to visualize the distribution of the living area

# %%
# Your code here
plt.figure(2, figsize=(8, 4))
plt.hist(living_area)
plt.xlabel("area (m^2)")
plt.title("area distribution")
plt.xlim(np.min(living_area), np.max(living_area))
plt.show()

# %% [markdown]
# c) Plot a scatter plot of renting price as a function of living area

# %%
# Your code here
plt.figure(3, figsize=(8, 4))
plt.scatter(living_area, rent_price)
plt.grid(True)
plt.xlabel('renting price (CHF)')
plt.ylabel('living area (m^2)')
plt.show()

# %% [markdown]
# ## Part 2 - Normal equations for linear regression - using numpy arrays

# %% [markdown]
# a) Implement the closed form solution to this problem using the following normal equation:

# %% [markdown]
# <div><div style="display: table-cell; width: 100%;"><center>$\theta = (X^{T}X)^{-1}X^{T}\vec{y}$</center></div><div style="display: table-cell; width: 100%;">$(3)$</div></div>

# %% [markdown]
# Assuming $x$ is the living area and $y$ is the renting price. Use `numpy` for the vector operations. Plot the computed line on top of the scatter plot of Part 1.

# %%
#######################################################################
# TODO:                                                               #
# Perform the following computation                                   #
#  - get N, the number of samples                                     #
#  - compose X with the 1st column full of 1.0 and the 2nd column     #
#    with the living area (hint: have a look to no.ones() and         #
#    np.column_stack()                                                #
#  - get y as the rent prices                                         #
#  - compute the theta (hint: matrix A to matrix B multiplication can #
#    be done with A.dot(B))                                           #
#  - plot the line (hint: compute a set of x points linearly spaced   #
#    and, with the thetas, compute the corresponding y values)        #
#######################################################################

N = len(living_area)
X = np.column_stack((np.ones(len(living_area)), living_area))
y = rent_price

# use Moore-Penrose pseudo inverse to solve over-determined equation system
theta = np.linalg.inv((X.T @ X)) @ X.T @ y

x_val = np.linspace(0, 250, num=N)
y_val = np.column_stack((np.ones(N), x_val)) @ theta

plt.figure(3, figsize=(8, 4))
plt.scatter(living_area, rent_price)
plt.grid(True)
plt.xlabel('renting price (CHF)')
plt.ylabel('living area (m^2)')

plt.plot(x_val, y_val, color='r')
plt.show()

#######################################################################
#                         END OF YOUR CODE                            #
#######################################################################

# %% [markdown]
# b) Compute the MSE loss according to the following equation:

# %% [markdown]
# <div><div style="display: table-cell; width: 100%;"><center>$J(\theta) = \frac{1}{2N} \sum_{n=1}^{N} (h_{\theta}(\mathbf{x}_{n}) - y_{n})^{2}$</center></div><div style="display: table-cell; width: 100%;">$(2)$</div></div>

# %%
#######################################################################
# TODO:                                                               #
#  - define a function h_theta(x, theta_0, theta_1) to compute the    #
#    the hypothesised values of y (the "y_hat")                       #
#  - define a function mse_loss(x, y, y_hat)                          #
#  - use both functions to compute the MSE loss on the dataset        #
#######################################################################

def h_theta(x, theta_0, theta_1):
    return np.column_stack((np.ones(N), x)) @ np.array([theta_0, theta_1])

def mse_loss(y, y_hat):
    return np.mean((y_hat-y)**2) / 2


print(f"MSE: {mse_loss(h_theta(living_area, theta[0], theta[1]), rent_price)}")


#######################################################################
#                         END OF YOUR CODE                            #
#######################################################################
# Out:
# MSE: 138034.95779787414

# %% [markdown]
# ## Part 3 - Normal equations for linear regression - using pytorch tensors
#
# Redo the part 2, this time using pytorch tensors.

# %%
#######################################################################
# TODO:                                                               #
# Perform the following computation                                   #
#  - in a similar way as in the previous part 2, compute theta0 and   #
#    theta1, plot the computed line                                   #
#  - compute the loss J with these new values of theta0 and theta1,   #
#    for that you may use mse_loss() function defined abouve          #
#######################################################################
import torch

N = len(living_area)
X = torch.tensor(np.column_stack((np.ones(len(living_area)), living_area)), dtype=torch.double)
y = torch.tensor(rent_price, dtype=torch.double)

theta = torch.linalg.lstsq(X, y).solution


x_val = np.linspace(0, 250, num=N)
y_val = np.column_stack((np.ones(N), x_val)) @ theta

plt.figure(3, figsize=(8, 4))
plt.scatter(living_area, rent_price)
plt.grid(True)
plt.xlabel('renting price (CHF)')
plt.ylabel('living area (m^2)')

plt.plot(x_val, y_val, color='r')
plt.show()

print(f"MSE: {mse_loss(h_theta(living_area, theta[0], theta[1]), rent_price)}")

#######################################################################
#                         END OF YOUR CODE                            #
#######################################################################
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8296\903002289.py in <module>
#      13 y = torch.tensor(rent_price, dtype=torch.double)
#      14
# ---> 15 theta = torch.linalg.lstsq(X, y).solution
#      16
#      17
#
# RuntimeError: Calling torch.linalg.lstsq on a CPU tensor requires compiling PyTorch with LAPACK. Please use PyTorch built with LAPACK support.
